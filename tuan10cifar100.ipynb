# %% [markdown]
# <a href="https://colab.research.google.com/github/vanquoc12/vVawnQuoc-20146406-tuan10/blob/main/tuan10cifar100.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.datasets import cifar100
import pandas as pd
(x_train,y_train),(x_test,y_test) = cifar100.load_data()
x_train.shape
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169001437/169001437 [==============================] - 9s 0us/step
# (50000, 32, 32, 3)

# %%
x_test.shape
# Out:
# (10000, 32, 32, 3)

# %%
import matplotlib.pyplot as plt
for i in range (20):
  plt.subplot(5,4,i+1)
  plt.tight_layout
  plt.imshow(x_train[i+1000],cmap='Blues',interpolation = 'None')
  plt.title('so nay la: {}'.format(y_train[i+1000]))
  plt.xticks([])
  plt.yticks([])

# %%
from keras.models import Sequential
from keras.layers import Dense
model = Sequential()
model.add(Dense(1024, activation = 'relu',input_shape=(32*32*3,)))
model.add(Dense(100, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1024)              3146752
#
#  dense_1 (Dense)             (None, 100)               102500
#
# =================================================================
# Total params: 3,249,252
# Trainable params: 3,249,252
# Non-trainable params: 0
# _________________________________________________________________

# %%
x_train = x_train.reshape((50000,32*32*3))
x_train = x_train.astype('float32')/255
x_train.shape
# Out:
# (50000, 3072)

# %%
x_test = x_test.reshape((10000,32*32*3))
x_test = x_test.astype('float32')/255
x_test.shape
# Out:
# (10000, 3072)

# %%
from keras.utils import to_categorical
y_train = to_categorical(y_train,100)
y_test=to_categorical(y_test,100)

# %%
model.compile(optimizer='rmsprop',loss='categorical_crossentropy',metrics=['accuracy'])
model.fit(x_train,y_train,epochs=50,batch_size=128)
test_loss,test_acc=model.evaluate(x_test,y_test)
print('Do mat mat:',test_loss)
print('Do chinh xac:',test_acc)
# Out:
# Epoch 1/50
# 391/391 [==============================] - 25s 60ms/step - loss: 4.2989 - accuracy: 0.0691
# Epoch 2/50
# 391/391 [==============================] - 25s 63ms/step - loss: 3.7709 - accuracy: 0.1295
# Epoch 3/50
# 391/391 [==============================] - 22s 57ms/step - loss: 3.6236 - accuracy: 0.1557
# Epoch 4/50
# 391/391 [==============================] - 24s 61ms/step - loss: 3.5262 - accuracy: 0.1752
# Epoch 5/50
# 391/391 [==============================] - 35s 91ms/step - loss: 3.4538 - accuracy: 0.1890
# Epoch 6/50
# 391/391 [==============================] - 24s 60ms/step - loss: 3.3953 - accuracy: 0.2011
# Epoch 7/50
# 391/391 [==============================] - 22s 57ms/step - loss: 3.3497 - accuracy: 0.2085
# Epoch 8/50
# 391/391 [==============================] - 23s 60ms/step - loss: 3.3059 - accuracy: 0.2169
# Epoch 9/50
# 391/391 [==============================] - 25s 63ms/step - loss: 3.2616 - accuracy: 0.2252
# Epoch 10/50
# 391/391 [==============================] - 24s 61ms/step - loss: 3.2360 - accuracy: 0.2313
# Epoch 11/50
# 391/391 [==============================] - 24s 60ms/step - loss: 3.2045 - accuracy: 0.2340
# Epoch 12/50
# 391/391 [==============================] - 23s 58ms/step - loss: 3.1741 - accuracy: 0.2430
# Epoch 13/50
# 391/391 [==============================] - 24s 60ms/step - loss: 3.1457 - accuracy: 0.2489
# Epoch 14/50
# 391/391 [==============================] - 24s 61ms/step - loss: 3.1184 - accuracy: 0.2558
# Epoch 15/50
# 391/391 [==============================] - 23s 60ms/step - loss: 3.0862 - accuracy: 0.2604
# Epoch 16/50
# 391/391 [==============================] - 25s 65ms/step - loss: 3.0617 - accuracy: 0.2647
# Epoch 17/50
# 391/391 [==============================] - 23s 58ms/step - loss: 3.0322 - accuracy: 0.2694
# Epoch 18/50
# 391/391 [==============================] - 23s 60ms/step - loss: 3.0043 - accuracy: 0.2764
# Epoch 19/50
# 391/391 [==============================] - 23s 60ms/step - loss: 2.9836 - accuracy: 0.2815
# Epoch 20/50
# 391/391 [==============================] - 23s 60ms/step - loss: 2.9555 - accuracy: 0.2876
# Epoch 21/50
# 391/391 [==============================] - 23s 58ms/step - loss: 2.9280 - accuracy: 0.2913
# Epoch 22/50
# 391/391 [==============================] - 24s 61ms/step - loss: 2.9066 - accuracy: 0.2959
# Epoch 23/50
# 391/391 [==============================] - 24s 60ms/step - loss: 2.8867 - accuracy: 0.3041
# Epoch 24/50
# 391/391 [==============================] - 24s 60ms/step - loss: 2.8552 - accuracy: 0.3082
# Epoch 25/50
# 391/391 [==============================] - 24s 61ms/step - loss: 2.8322 - accuracy: 0.3111
# Epoch 26/50
# 391/391 [==============================] - 23s 58ms/step - loss: 2.8034 - accuracy: 0.3204
# Epoch 27/50
# 391/391 [==============================] - 24s 61ms/step - loss: 2.7792 - accuracy: 0.3258
# Epoch 28/50
# 391/391 [==============================] - 24s 61ms/step - loss: 2.7553 - accuracy: 0.3291
# Epoch 29/50
# 391/391 [==============================] - 24s 61ms/step - loss: 2.7378 - accuracy: 0.3335
# Epoch 30/50
# 391/391 [==============================] - 24s 61ms/step - loss: 2.7063 - accuracy: 0.3411
# Epoch 31/50
# 391/391 [==============================] - 22s 57ms/step - loss: 2.6815 - accuracy: 0.3458
# Epoch 32/50
# 391/391 [==============================] - 24s 60ms/step - loss: 2.6588 - accuracy: 0.3533
# Epoch 33/50
# 391/391 [==============================] - 24s 61ms/step - loss: 2.6292 - accuracy: 0.3560
# Epoch 34/50
# 391/391 [==============================] - 24s 60ms/step - loss: 2.6102 - accuracy: 0.3594
# Epoch 35/50
# 391/391 [==============================] - 23s 60ms/step - loss: 2.5883 - accuracy: 0.3666
# Epoch 36/50
# 391/391 [==============================] - 23s 58ms/step - loss: 2.5662 - accuracy: 0.3707
# Epoch 37/50
# 391/391 [==============================] - 24s 61ms/step - loss: 2.5415 - accuracy: 0.3770
# Epoch 38/50
# 391/391 [==============================] - 24s 61ms/step - loss: 2.5190 - accuracy: 0.3816
# Epoch 39/50
# 391/391 [==============================] - 24s 61ms/step - loss: 2.4937 - accuracy: 0.3852
# Epoch 40/50
# 391/391 [==============================] - 24s 61ms/step - loss: 2.4794 - accuracy: 0.3908
# Epoch 41/50
# 391/391 [==============================] - 23s 58ms/step - loss: 2.4460 - accuracy: 0.3990
# Epoch 42/50
# 391/391 [==============================] - 24s 61ms/step - loss: 2.4372 - accuracy: 0.4011
# Epoch 43/50
# 391/391 [==============================] - 24s 61ms/step - loss: 2.4016 - accuracy: 0.4063
# Epoch 44/50
# 391/391 [==============================] - 24s 61ms/step - loss: 2.3809 - accuracy: 0.4136
# Epoch 45/50
# 391/391 [==============================] - 24s 60ms/step - loss: 2.3578 - accuracy: 0.4173
# Epoch 46/50
# 391/391 [==============================] - 23s 58ms/step - loss: 2.3455 - accuracy: 0.4210
# Epoch 47/50
# 391/391 [==============================] - 24s 61ms/step - loss: 2.3245 - accuracy: 0.4248
# Epoch 48/50
# 391/391 [==============================] - 24s 61ms/step - loss: 2.3099 - accuracy: 0.4297
# Epoch 49/50
# 391/391 [==============================] - 24s 61ms/step - loss: 2.2718 - accuracy: 0.4358
# Epoch 50/50
# 391/391 [==============================] - 24s 61ms/step - loss: 2.2657 - accuracy: 0.4388
# 313/313 [==============================] - 4s 12ms/step - loss: 4.8709 - accuracy: 0.2002
# Do mat mat: 4.870893955230713
# Do chinh xac: 0.20020000636577606

# %%
from keras.utils import load_img, img_to_array
import numpy as np

img =plt.imread('/content/images.jpg')
plt.imshow(img)
plt.show()

img = load_img('/content/images.jpg',target_size=(32,32))
img = img_to_array(img)
img=img.reshape(1,32*32*3)
img =img.astype('float32')
img = img/255
np.argmax(model.predict(img),axis=-1)
# Out:
# 1/1 [==============================] - 0s 220ms/step
# array([95])
